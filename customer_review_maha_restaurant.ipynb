0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 kB 3.1 MB/s eta 0:00:00

# %%
from langchain_community.llms import Replicate
import os
from google.colab import userdata
# Set the API token
api_token = userdata.get('api_token')
os.environ["REPLICATE_API_TOKEN"] = api_token
# Model setup
model = "ibm-granite/granite-3.2-8b-instruct"
output = Replicate(
model=model,
replicate_api_token=api_token,
)

# %%
# Define the customer reviews
customer_reviews = [
"We had lunch at Maha restaurant in Melbourne CBD and it was absolute perfection. We ordered some starters to share and particularly loved the beef dumpling dish. We then decided to share our mains as well- the slow cooked lamb shoulder, wagyu beef, duck and snapper. Each flavour was more tantalising than the next. Our cocktails and mocktails were perfectly paired to enhance the flavours. Maha has a lovely moody ambiance and the interior styling is a dream. The only thing I would have liked more would be a small table light to help with reading the menus. But next time I visit, I’ll know what dishes to order. I highly recommend Maha.",
"Had an absolute amazing lunch at Maha. The roasted scallops are to die for! The lamb shoulder was melt in your mouth. And the bread - OMG - was the best I’ve ever had in my life. Would definitely return!.",
"There's a definite cynicism to the offer here. The flavours feel subdued in some of the courses. The tuna is wonderfully flavoured, but was there 30g there? The olive palate cleanser was the only item I'd return for. But I won't The dessert was good, though every element was sweetened, leaving my blood sugar at pre marathon levels. The lamb shoulder wasn't properly processed for fine dining and bland. The hummus and bread were good enough, but the harissa...well..it wasn't, and neither was the dish, which found its pasta element unevenly cooked. The service was quite good if not a bit weirdly lingering/hovering at times (then again, I am incredibly good-looking), and the room plush, but the seats somehow very uncomfortable, and the banquette so cheap as to move around with me (again, my attraction at work, or is that play?). All in all, it's top $ for a meal with a few pleasant moments, 1 remarkable moment, and a few deflationary ones. The wines by the glass are unevenly poured and not particularly good. There's better all over Melbourne. And minus one star to 2, just because i never want to return.",
"Maha consistently impresses! Celebrating my birthday there for the fourth time was magical. The vegan Signature Experience menu was a culinary delight, with each dish showcasing incredible creativity and flavor. The ambiance and service elevate the experience, making it a must-visit for anyone seeking an extraordinary meal. Highly recommended!",
"We went there last night for my wife’s Birthday, they gave us a sit next to the bar which was extremely busy with staff walking by, bar staff making cocktails all the time and very cold! It was a nice seat but not for $300 dinner! Maybe for drinks! We asked the staff to change our seats, but the manager told us there is no other seats available, we went to toilet and saw many seats available, ask them about the empty seats, manager said they are all fully booked! We had a booking too! The manager was not welcoming at all! And was not there to fix the problem! She wanted to change our mind! We decided to leave! They told us we need to pay $140 pp!! She said there is a seat 2 h later, or another seat which we can sit for only 45 min! Obviously we didnt want that! The manager was not listening, keep saying, this is how it is! Sit here or pay 280 and leave! Finally she said there is a seat available for us in the main dining room! Went there, two table behind us was empty for the whole 3h we were there!! I will upload the photo! Really bad experience! Would never go back! Food: It was cold. Too much beans! Got stomach ache after entrées. Main dish, we got chicken with truffle, was juicy but flavour less, too much salt! Drinks: we got cocktails which was really good. Atmosphere, was nice and elegant, seats were comfortable. Staff were nice and well trained except the manager! Liby was extremely nice and welcoming! We got charged extra $3.9 at the end, dont know why! It was not holiday or Sunday! I dont recommend going there, it really doesnt worth it! Really! In case the Maha team wants to know the details, it was booked for 2 under name Maryam at 6:30 27 Jun",
"Loved our lunch here, we really enjoyed the escape it provided from our work day, the lower light inside allowed for nice setting with the gold flecks in the decor giving allegiance. We will be back to enjoy the menu other amazing options that were on the menu. Highly recommend finishing with a coffee and Turkish donuts!"

]

# Refine the prompt to include reviews
reviews_text = "\n".join([f"Review {i+1}: {review}" for i, review
in enumerate(customer_reviews)])
prompt = f"""
Classify all reviews into three categories Positive, Negative, or Mixed:
{reviews_text}
"""
# Invoke the model with the example prompt
response = output.invoke(prompt)
# Print the response
print("Granite Model Response:\n")
print(response)
# Out:
# Granite Model Response:
#
# Review 1: Positive
# Review 2: Positive
# Review 3: Negative
# Review 4: Positive
# Review 5: Negative
# Review 6: Positive

# %%
# Define refined prompt
refined_prompt = f"""
Classify these reviews as positive, negative, or mixed, and tag
relevant categories (food quality, customer service, or
atmosphere):
{reviews_text}
"""
# Invoke the model with the example prompt
response = output.invoke(refined_prompt)
# Print the response
print("Granite Model Refined Response:\n")
print(response)
# Out:
# Granite Model Refined Response:
#
# Review 1: Positive (Food Quality, Atmosphere)
# - The review is overwhelmingly positive, praising the food quality, particularly the starters and mains, and the atmosphere.
#
# Review 2: Positive (Food Quality)
# - This review is highly positive, focusing on the exceptional quality of the roasted scallops, lamb shoulder, and bread.
#
# Review 3: Mixed (Food Quality, Atmosphere, Customer Service)
# - This review is mixed. While the reviewer enjoyed some elements like the roasted scallops and bread, they criticized the food quality of other dishes, the service, and the seating comfort.
#
# Review 4: Positive (Food Quality, Atmosphere, Customer Service)
# - This review is very positive, praising the vegan Signature Experience menu, the ambiance, and the service.
#
# Review 5: Negative (Customer Service, Food Quality)
# ...

# %%
# Define the prompt to complete the task in 2 steps
multitask_prompt = f"""
Complete the task in 2 steps.
Step 1: Classify these reviews as positive, negative, or mixed.
Step 2: For each review, identify relevant categories: food quality, service, or atmosphere.
{reviews_text}
"""
response = output.invoke(multitask_prompt)
print("Granite Model Response:\n")
print(response)
# Out:
# Granite Model Response:
#
# Step 1: Classifying the reviews
#
# 1. Positive: This review is overwhelmingly positive. The reviewer praises the food, drinks, ambiance, and overall experience, and highly recommends Maha.
# 2. Positive: This review is highly positive, focusing on the exceptional quality of the roasted scallops and lamb shoulder, and expresses a desire to return.
# 3. Mixed: This review has both positive and negative elements. While the reviewer appreciates certain dishes and the ambiance, they criticize others, finding faults in the flavors, portion sizes, service, and comfort of the seating.
# 4. Positive: This review is extremely positive, highlighting the consistency of Maha's quality, the creativity of the vegan menu, and the excellent ambiance and service, making it a must-visit place.
# ...

# %%
# Define the example to guide the model
formatted_prompt = f"""
Classify these reviews as Positive, Negative, or Mixed, and tag
relevant categories. Use this format:
- Sentiment: [Sentiment]
- Categories: [Categories].

{reviews_text}
"""
# Invoke the model with prompt
response = output.invoke(formatted_prompt)
# Print the response
print("Granite Model Formatted Response:\n")
print(response)
# Out:
# Granite Model Formatted Response:
#
# - Sentiment: Positive
#   - Categories: Ambiance, Menu, Service, Value
#
# - Sentiment: Positive
#   - Categories: Menu, Flavor, Service
#
# - Sentiment: Negative
#   - Categories: Flavor, Service, Ambiance, Value
#
# - Sentiment: Positive
#   - Categories: Ambiance, Menu, Service, Value (specifically for vegan options)
#
# - Sentiment: Negative
#   - Categories: Service, Seating, Food, Value
#
# - Sentiment: Positive
#   - Categories: Ambiance, Menu, Service (excluding management)
